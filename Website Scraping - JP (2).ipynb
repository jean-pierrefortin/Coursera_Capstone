# %%
import requests
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
import ssl
import csv
from urllib.request import urlopen #Download all neccessary libraries

# %%
URL = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
page = requests.get(URL).text
soup = BeautifulSoup(page, 'lxml') #naming data crucial for scraping the data on website

# %%
ctx = ssl.create_default_context() 
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE #SSL errors

# %%
data_table = soup.find('table',{'class':'wikitable sortable'})
data_rows = data_table.find_all('tr') # find all table rows on website link

# %%
table = [] 
for row in data_rows:
    table.append([t.text.strip() for t in row.find_all('td')]) #append to table all rows that are scraped from link
# Out:
#   PostalCode           Borough     Neighbourhood
# 1        M1A      Not assigned      Not assigned
# 2        M2A      Not assigned      Not assigned
# 3        M3A        North York         Parkwoods
# 4        M4A        North York  Victoria Village
# 5        M5A  Downtown Toronto      Harbourfront

# %%
df = pd.DataFrame(table, columns=['PostalCode', 'Borough', 'Neighbourhood'])
df = df[df['PostalCode'].notnull()] #pull all values with not null in columns
df.head() #Display frist 5 rows of data table
# Out:
#   PostalCode           Borough     Neighbourhood
# 1        M1A      Not assigned      Not assigned
# 2        M2A      Not assigned      Not assigned
# 3        M3A        North York         Parkwoods
# 4        M4A        North York  Victoria Village
# 5        M5A  Downtown Toronto      Harbourfront

# %%
df.drop(df[df['Borough'] == 'Not assigned'].index, axis=0, inplace = True) #drop all True values for Not assigned in Borough

# %%
df.shape #express shape of dataframe
# Out:
# (210, 3)

# %%
df2 = df.groupby('PostalCode').agg(lambda x: ','.join(x)) # group ALL with same PostCode name in same Column
df2 #Display data table
# Out:
#                                                       Borough  \
# PostalCode
# M1B                                   Scarborough,Scarborough
# M1C                       Scarborough,Scarborough,Scarborough
# M1E                       Scarborough,Scarborough,Scarborough
# M1G                                               Scarborough
# M1H                                               Scarborough
# M1J                                               Scarborough
# M1K                       Scarborough,Scarborough,Scarborough
# M1L                       Scarborough,Scarborough,Scarborough
# M1M                       Scarborough,Scarborough,Scarborough
# M1N                                   Scarborough,Scarborough
# M1P                       Scarborough,Scarborough,Scarborough
# M1R                                   Scarborough,Scarborough
# M1S                                               Scarborough
# M1T                       Scarborough,Scarborough,Scarborough
# ...

# %%
df2.reset_index() #reset index to data table
# Out:
#     PostalCode                                            Borough  \
# 0          M1B                            Scarborough,Scarborough
# 1          M1C                Scarborough,Scarborough,Scarborough
# 2          M1E                Scarborough,Scarborough,Scarborough
# 3          M1G                                        Scarborough
# 4          M1H                                        Scarborough
# 5          M1J                                        Scarborough
# 6          M1K                Scarborough,Scarborough,Scarborough
# 7          M1L                Scarborough,Scarborough,Scarborough
# 8          M1M                Scarborough,Scarborough,Scarborough
# 9          M1N                            Scarborough,Scarborough
# 10         M1P                Scarborough,Scarborough,Scarborough
# 11         M1R                            Scarborough,Scarborough
# 12         M1S                                        Scarborough
# ...

# %%
df2.loc[df2['Neighbourhood']=="Not assigned",'Neighbourhood']=df2.loc[df2['Neighbourhood']=="Not assigned",'Borough'] 
#locate "Not assigned in Neighborhood col & replace with Borough"
df2 # Display data table
# Out:
#                                                       Borough  \
# PostalCode
# M1B                                   Scarborough,Scarborough
# M1C                       Scarborough,Scarborough,Scarborough
# M1E                       Scarborough,Scarborough,Scarborough
# M1G                                               Scarborough
# M1H                                               Scarborough
# M1J                                               Scarborough
# M1K                       Scarborough,Scarborough,Scarborough
# M1L                       Scarborough,Scarborough,Scarborough
# M1M                       Scarborough,Scarborough,Scarborough
# M1N                                   Scarborough,Scarborough
# M1P                       Scarborough,Scarborough,Scarborough
# M1R                                   Scarborough,Scarborough
# M1S                                               Scarborough
# M1T                       Scarborough,Scarborough,Scarborough
# ...

# %%
df2['Borough']= df2['Borough'].str.replace('nan|[{}\s]','').str.split(',').apply(set).str.join(',').str.strip(',').str.replace(",{2,}",",") 
#take out duplicates in "Borough" column

# %%
df_main = df2.reset_index() #reset index after taking out duplicates and creating new dataframe name
df_main.head() #display first 5 rows of new table after reseting index
# Out:
#   PostalCode      Borough                         Neighbourhood
# 0        M1B  Scarborough                         Rouge,Malvern
# 1        M1C  Scarborough  Highland Creek,Rouge Hill,Port Union
# 2        M1E  Scarborough       Guildwood,Morningside,West Hill
# 3        M1G  Scarborough                                Woburn
# 4        M1H  Scarborough                             Cedarbrae

# %%
df_main.shape #Display shape of dataframe
# Out:
# (103, 3)

# %%
coords_file = 'http://cocl.us/Geospatial_data' #convert coordinates file into dataframe
Coords = pd.read_csv(coords_file)

# %%
Coords.head() #Display new file
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
Coords.rename(columns={"Postal Code": "PostalCode"}, inplace=True) #rename Columns to PostalCode
Coords.head()
# Out:
#   PostalCode   Latitude  Longitude
# 0        M1B  43.806686 -79.194353
# 1        M1C  43.784535 -79.160497
# 2        M1E  43.763573 -79.188711
# 3        M1G  43.770992 -79.216917
# 4        M1H  43.773136 -79.239476

# %%
df3 = df_main.merge(Coords, on="PostalCode", how="left") #Merge df_main with new file with coordinates, add to appropriate PostalCode
df3.head() #Display first 5 rows of new file with coordinates
# Out:
#   PostalCode      Borough                         Neighbourhood   Latitude  \
# 0        M1B  Scarborough                         Rouge,Malvern  43.806686
# 1        M1C  Scarborough  Highland Creek,Rouge Hill,Port Union  43.784535
# 2        M1E  Scarborough       Guildwood,Morningside,West Hill  43.763573
# 3        M1G  Scarborough                                Woburn  43.770992
# 4        M1H  Scarborough                             Cedarbrae  43.773136
#
#    Longitude
# 0 -79.194353
# 1 -79.160497
# 2 -79.188711
# 3 -79.216917
# 4 -79.239476

# %%
df3
# Out:
#     PostalCode          Borough  \
# 0          M1B      Scarborough
# 1          M1C      Scarborough
# 2          M1E      Scarborough
# 3          M1G      Scarborough
# 4          M1H      Scarborough
# 5          M1J      Scarborough
# 6          M1K      Scarborough
# 7          M1L      Scarborough
# 8          M1M      Scarborough
# 9          M1N      Scarborough
# 10         M1P      Scarborough
# 11         M1R      Scarborough
# 12         M1S      Scarborough
# 13         M1T      Scarborough
# 14         M1V      Scarborough
# 15         M1W      Scarborough
# 16         M1X      Scarborough
# 17         M2H        NorthYork
# 18         M2J        NorthYork
# 19         M2K        NorthYork
# 20         M2L        NorthYork
# 21         M2M        NorthYork
# 22         M2N        NorthYork
# 23         M2P        NorthYork
# 24         M2R        NorthYork
# 25         M3A        NorthYork
# 26         M3B        NorthYork
# 27         M3C        NorthYork
# ...
